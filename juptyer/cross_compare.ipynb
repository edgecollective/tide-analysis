# %%
import pandas as pd

# %%
feed_a_pubkey = "xygzemcr5jcw" # modify this to match a public key on belfast.pvos.org
feed_b_pubkey = "8sya5bx3xyic" # modify this to match another public key on belfast.pvos.org

# code below will plot the 'distance_meters' parameter from both of those feeds on the same chart
base_url = "http://belfast.pvos.org/data/"
feed_a_data = pd.read_csv(base_url+feed_a_pubkey+"/csv/")
feed_b_data = pd.read_csv(base_url+feed_b_pubkey+"/csv/")

x1=feed_a_data['timestamp']
y1=feed_a_data['distance_meters']

x2=feed_b_data['timestamp']
y2=feed_b_data['distance_meters']

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.figure(figsize=(12, 10))
plt.plot(x1,y1,label=feed_a_pubkey)
plt.plot(x2,y2,label=feed_b_pubkey)
plt.grid(True)
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# # Note on date formatting graphs
# Nice bit on how to 'beautify' the dates on the x-axis [here](https://stackoverflow.com/questions/14946371/editing-the-date-formatting-of-x-axis-tick-labels-in-matplotlib).
#
# Associated matplotlib date options are listed [here](https://matplotlib.org/2.0.2/examples/api/date_demo.html).
